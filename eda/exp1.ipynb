# %%
import pandas as pd

import pymorphy3

# %%
classification = pd.read_excel("../data/train_Ametist/classification.xlsx")
train_data = pd.read_excel("../data/train_Ametist/train.xlsx")

# %%
def extract_group(text, taget="Группа"):
    text = str(text)
    if taget in text:
        return text.split(":")[-1].replace(f"{taget} ", "").strip()
    return None

# %%
classification["group"] = classification["Классификатор строительных ресурсов"].apply(
    lambda x: extract_group(x, "Группа")
)
classification["group"] = classification["group"].fillna(method="ffill")

# %%
classification["book"] = classification["Классификатор строительных ресурсов"].apply(
    lambda x: extract_group(x, "Книга")
)
classification["book"] = classification["book"].fillna(method="ffill")

# %%
classification["part"] = classification["Классификатор строительных ресурсов"].apply(
    lambda x: extract_group(x, "Раздел")
)
classification["part"] = classification["part"].fillna(method="ffill")

# %%
clear_mask = (
    classification.dropna(axis=0, how="any")
    .iloc[:, 0]
    .apply(lambda x: all(c in "0123456789.- " for c in x))
)

cleared_classification = classification.dropna(axis=0, how="any")[clear_mask].rename(
    columns={
        "Классификатор строительных ресурсов": "code",
        "Unnamed: 1": "name",
        "Unnamed: 2": "measure",
    }
)

# %%
cleared_classification = cleared_classification[
    cleared_classification["code"].apply(lambda x: len(x.split("."))) > 4
].reset_index(drop=True)
cleared_classification.head()
# Out:
#                                code
# 0  23.65.12.190.01.1.01.01-0002-000  \
# 1  23.65.12.190.01.1.01.02-0011-000
# 2  23.65.12.111.01.1.01.04-1018-000
# 3  23.65.12.111.01.1.01.04-1022-000
# 4  23.65.12.111.01.1.01.04-1024-000
#
#                                                 name    measure
# 0  Детали фасонные коньковые к листам хризотилцем...  100 компл  \
# 1  Доска электротехническая дугостойкая (АЦЭИД), ...          т
# 2  Листы хризотилцементные волнистые, профиль 40/...         м2
# 3  Листы хризотилцементные волнистые, профиль 40/...         м2
# 4  Листы хризотилцементные волнистые, профиль 40/...         м2
#
#                                         group
# 0  Детали фасонные к листам хризотилцементным  \
# 1                    Доски электротехнические
# 2           Листы хризотилцементные волнистые
# 3           Листы хризотилцементные волнистые
# 4           Листы хризотилцементные волнистые
#
#                                           book
# 0  Материалы для строительных и дорожных работ  \
# 1  Материалы для строительных и дорожных работ
# 2  Материалы для строительных и дорожных работ
# 3  Материалы для строительных и дорожных работ
# 4  Материалы для строительных и дорожных работ
#
#                                                 part
# 0  Материалы, изделия и конструкции хризотилсодер...
# 1  Материалы, изделия и конструкции хризотилсодер...
# 2  Материалы, изделия и конструкции хризотилсодер...
# 3  Материалы, изделия и конструкции хризотилсодер...
# 4  Материалы, изделия и конструкции хризотилсодер...

# %%
clsf = cleared_classification

# %%
morph = pymorphy3.MorphAnalyzer()
lemm_texts_list = []

for text in clsf["name"]:
    text_lem = [morph.parse(word)[0].normal_form for word in text.split(" ")]
    if len(text_lem) <= 2:
        lemm_texts_list.append("")
        continue
    lemm_texts_list.append(" ".join(text_lem))
clsf["text_lemm"] = lemm_texts_list
clsf = clsf[clsf["text_lemm"] != ""]
clsf.head()
# Out:
#                                code
# 0  23.65.12.190.01.1.01.01-0002-000  \
# 1  23.65.12.190.01.1.01.02-0011-000
# 2  23.65.12.111.01.1.01.04-1018-000
# 3  23.65.12.111.01.1.01.04-1022-000
# 4  23.65.12.111.01.1.01.04-1024-000
#
#                                                 name    measure
# 0  Детали фасонные коньковые к листам хризотилцем...  100 компл  \
# 1  Доска электротехническая дугостойкая (АЦЭИД), ...          т
# 2  Листы хризотилцементные волнистые, профиль 40/...         м2
# 3  Листы хризотилцементные волнистые, профиль 40/...         м2
# 4  Листы хризотилцементные волнистые, профиль 40/...         м2
#
#                                         group
# 0  Детали фасонные к листам хризотилцементным  \
# 1                    Доски электротехнические
# 2           Листы хризотилцементные волнистые
# 3           Листы хризотилцементные волнистые
# 4           Листы хризотилцементные волнистые
#
#                                           book
# 0  Материалы для строительных и дорожных работ  \
# 1  Материалы для строительных и дорожных работ
# 2  Материалы для строительных и дорожных работ
# 3  Материалы для строительных и дорожных работ
# 4  Материалы для строительных и дорожных работ
#
#                                                 part
# 0  Материалы, изделия и конструкции хризотилсодер...  \
# 1  Материалы, изделия и конструкции хризотилсодер...
# 2  Материалы, изделия и конструкции хризотилсодер...
# 3  Материалы, изделия и конструкции хризотилсодер...
# 4  Материалы, изделия и конструкции хризотилсодер...
#
#                                            text_lemm
# 0  деталь фасонный коньковый к лист хризотилцемен...
# 1  доска электротехнический дугостойкий (ацэид), ...
# 2  лист хризотилцементный волнистые, профиль 40/1...
# 3  лист хризотилцементный волнистые, профиль 40/1...
# 4  лист хризотилцементный волнистые, профиль 40/1...

# %%
del lemm_texts_list

# %%
print(clsf["book"].nunique())
print(clsf["part"].nunique())
print(clsf["group"].nunique())
# Out:
# 39
# 463
# 2076

# %%
from sklearn.model_selection import train_test_split
import re


def cut_code(code):
    split_code = re.split(r"\.|-", code)
    return int("".join(split_code[:-9]))


X = clsf["text_lemm"]
y = clsf["code"].apply(lambda x: cut_code(x))
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

# %%
from catboost import CatBoostClassifier, Pool


def fit_model(train_pool, test_pool, **kwargs):
    model = CatBoostClassifier(
        task_type="GPU", eval_metric="TotalF1", od_type="Iter", od_wait=10, **kwargs
    )

    return model.fit(
        train_pool, eval_set=test_pool, verbose=1, plot=False, use_best_model=True
    )

# %%
train_pool = Pool(
    data=X_train,
    label=y_train,
    text_features=[X_train.name],
    feature_names=[X_train.name],
)
valid_pool = Pool(
    data=X_test.reset_index(drop=True),
    label=y_test,
    text_features=[X_train.name],
    feature_names=[X_train.name],
)

# %%
pd.concat([X_train, y_train], axis=1).head(100)
# Out:
#                                                 text_lemm  code
# 87892   кабель волоконно-оптический, повить стеклоните...    27
# 74      прокладка паронитовый для опорный кронштейна, ...    23
# 100711  опора унифицировать стальной анкерно-угловой с...    25
# 47394   плита опорный для трубчатый винтовой штанга 30...    25
# 6056    смесь сухой теплоизоляционный на основа полист...    23
# ...                                                   ...   ...
# 3883    борфреза тип f, диаметр режущий часть 16 мм, д...    25
# 94181   переход бесшовный эксцентрический из нержавеющ...    24
# 72285   клапан запорный с.кзсг 15-00-00-эн, исполнение...    28
# 164:	learn: 0.9502594	test: 0.9628162	best: 0.9628162 (163)	total: 11.5s	remaining: 9.42s
# 165:	learn: 0.9503502	test: 0.9629067	best: 0.9629067 (165)	total: 11.6s	remaining: 9.34s
# 166:	learn: 0.9503381	test: 0.9630013	best: 0.9630013 (166)	total: 11.6s	remaining: 9.27s
# 167:	learn: 0.9504418	test: 0.9630951	best: 0.9630951 (167)	total: 11.7s	remaining: 9.19s
# 168:	learn: 0.9505332	test: 0.9631668	best: 0.9631668 (168)	total: 11.8s	remaining: 9.12s
# 169:	learn: 0.9505665	test: 0.9631668	best: 0.9631668 (168)	total: 11.8s	remaining: 9.04s
# 170:	learn: 0.9506117	test: 0.9631668	best: 0.9631668 (168)	total: 11.9s	remaining: 8.97s
# 171:	learn: 0.9506502	test: 0.9631183	best: 0.9631668 (168)	total: 12s	remaining: 8.89s
# 172:	learn: 0.9507283	test: 0.9631163	best: 0.9631668 (168)	total: 12s	remaining: 8.82s
# 173:	learn: 0.9507619	test: 0.9631183	best: 0.9631668 (168)	total: 12.1s	remaining: 8.75s
# 174:	learn: 0.9507926	test: 0.9631175	best: 0.9631668 (168)	total: 12.2s	remaining: 8.68s
# 175:	learn: 0.9507807	test: 0.9631165	best: 0.9631668 (168)	total: 12.2s	remaining: 8.6s
# 176:	learn: 0.9508507	test: 0.9629758	best: 0.9631668 (168)	total: 12.3s	remaining: 8.52s
# 177:	learn: 0.9509918	test: 0.9630704	best: 0.9631668 (168)	total: 12.3s	remaining: 8.45s
# 178:	learn: 0.9509802	test: 0.9630711	best: 0.9631668 (168)	total: 12.4s	remaining: 8.38s
# bestTest = 0.9631667842
# bestIteration = 168
# Shrink model to first 169 iterations.

# %%
val_data = pd.read_excel("../data/train_Ametist/train.xlsx")
val_data.head()
# Out:
#                                        record_name
# 0  DIN -рейка оцинкованная ТН35-7.5 100 см (Chint)  \
# 1              Анкерный элемент ТехноНиколь 8*45мм
# 2               Анкер забивной М10 DRM 12x40 сталь
# 3                         Анкер забивной М10/12x40
# 4                     Анкер забивной М8 LAZ латунь
#
#                         record_name_2                          ref_code
# 0  DIN-рейка 35х7,5 мм длиной 1000 мм  27.33.13.130.20.2.08.01-0001-000  \
# 1           Анкерный элемент TN 8x4.5  25.94.11.190.01.7.15.01-1169-000
# 2                 Анкер втулочный M10  25.94.11.190.01.7.15.01-0037-000
# 3                 Анкер втулочный M10  25.94.11.190.01.7.15.01-0037-000
# 4                  Анкер втулочный M8  25.94.11.190.01.7.15.01-0036-000
#
#                                             ref_name ref_unit
# 0  DIN-рейки металлические, оцинкованные, размеры...   100 шт
# 1  Анкер грунтовый забивной самораскрывающийся, о...       шт
# 2  Анкер забивной латунный, диаметр внутренней ре...       шт
# 3  Анкер забивной латунный, диаметр внутренней ре...       шт
# 4  Анкер забивной латунный, диаметр внутренней ре...       шт

# %%
lemm_texts_list = []

for text in val_data["record_name"]:
    text_lem = [morph.parse(word)[0].normal_form for word in text.split(" ")]
    if len(text_lem) <= 2:
        lemm_texts_list.append("")
        continue
    lemm_texts_list.append(" ".join(text_lem))
val_data["text_lemm"] = lemm_texts_list
val_data = val_data[val_data["text_lemm"] != ""]
val_data.head()
# Out:
#                                        record_name
# 0  DIN -рейка оцинкованная ТН35-7.5 100 см (Chint)  \
# 1              Анкерный элемент ТехноНиколь 8*45мм
# 2               Анкер забивной М10 DRM 12x40 сталь
# 3                         Анкер забивной М10/12x40
# 4                     Анкер забивной М8 LAZ латунь
#
#                         record_name_2                          ref_code
# 0  DIN-рейка 35х7,5 мм длиной 1000 мм  27.33.13.130.20.2.08.01-0001-000  \
# 1           Анкерный элемент TN 8x4.5  25.94.11.190.01.7.15.01-1169-000
# 2                 Анкер втулочный M10  25.94.11.190.01.7.15.01-0037-000
# 3                 Анкер втулочный M10  25.94.11.190.01.7.15.01-0037-000
# 4                  Анкер втулочный M8  25.94.11.190.01.7.15.01-0036-000
#
#                                             ref_name ref_unit
# 0  DIN-рейки металлические, оцинкованные, размеры...   100 шт  \
# 1  Анкер грунтовый забивной самораскрывающийся, о...       шт
# 2  Анкер забивной латунный, диаметр внутренней ре...       шт
# 3  Анкер забивной латунный, диаметр внутренней ре...       шт
# 4  Анкер забивной латунный, диаметр внутренней ре...       шт
#
#                                            text_lemm
# 0  din -рейка оцинковать тн35-7.5 100 смотреть (c...
# 1               анкерный элемент технониколь 8*45мма
# 2                 анкер забивной м10 drm 12x40 сталь
# 3                           анкер забивной м10/12x40
# 4                       анкер забивной м8 laz латунь

# %%
model.feature_names_
# Out:
# ['text_lemm']

# %%
# test_pool = Pool(
#     data=clsf["text_lemm"].reset_index(drop=True),
#     text_features=["text_lemm"],
#     feature_names=["text_lemm"],
# )
cnt = 0
for i, x in enumerate(model.predict(train_pool)):
    if int(x[0]) == int(clsf["code"].iloc[i].split(".")[0]):
        cnt += 1
print(cnt / len(X_train))
# Out:
# 0.16405467713014926

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.metrics.pairwise import (
    cosine_distances,
    haversine_distances,
    euclidean_distances,
)
import numpy as np
import heapq

# %%
cv = CountVectorizer(analyzer="char_wb", ngram_range=(3, 5))
X = cv.fit_transform(clsf["text_lemm"])

# %%
def get_lemm(text):
    text_lem = [morph.parse(word)[0].normal_form for word in text.split(" ")]
    return " ".join(text_lem)

# %%
scores = []
for i, r in val_data.iterrows():
    Y = cv.transform(list(map(get_lemm, [r["text_lemm"]])))
    found = clsf["code"].iloc[np.argmin(cosine_distances(X, Y))]
    real = r["ref_code"]
    print(found)
    print(real)
    cnt = 0
    max_len = max(len(found), len(real))
    for i in range(max_len):
        if found[i] == real[i]:
            cnt += 1
        else:
            break
    print(cnt / max_len)
    scores.append(cnt / max_len)
# Out:
# 25.94.11.110.01.7.15.02-0054-000
# 27.33.13.130.20.2.08.01-0001-000
# 0.03125
# 25.11.23.119.59.1.25.03-3541-000
# 25.94.11.190.01.7.15.01-1169-000
# 0.09375
# 25.94.11.190.01.7.15.01-0038-000
# 25.94.11.190.01.7.15.01-0037-000
# 0.84375

# 25.94.11.120.59.1.01.07-1229-000
# 25.94.11.110.01.7.15.03-0012-000
# 0.3125
# 25.94.11.110.01.7.15.03-0038-000
# 25.94.11.110.01.7.15.03-0019-000
# 0.8125
# 25.94.11.110.01.7.15.03-0038-000
# 25.94.11.110.01.7.15.03-0019-000
# 0.8125
# 25.94.11.110.59.1.01.07-1048-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.40625
# 25.94.11.110.59.1.01.07-1048-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.40625
# 25.94.11.120.59.1.01.07-1229-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.3125
# 25.94.11.120.59.1.01.07-1229-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.3125
# 25.94.11.120.59.1.01.07-1229-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.3125
# 25.94.11.120.59.1.01.07-1229-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.3125
# 25.94.11.120.59.1.01.07-1229-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.3125
# 25.94.11.120.59.1.01.07-1229-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.3125
# 25.94.11.120.59.1.01.07-1229-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.3125
# 25.94.11.120.59.1.01.07-1229-000
# 25.94.11.110.01.7.15.03-0011-000
# 0.3125
# 25.94.11.110.01.7.15.03-0034-000
# 25.94.11.110.22.2.02.11-0022-000
# 0.40625
# 25.94.11.130.59.1.20.02-2932-000
# 25.94.11.110.22.2.02.11-0022-000
# 0.3125
# 25.94.11.190.08.4.01.01-0030-000
# 25.94.11.110.22.2.02.11-0022-000
# 0.3125
# 25.94.11.110.01.7.15.02-0054-000
# 25.94.11.110.22.2.02.11-0021-000
# 0.40625
# 25.94.11.110.01.7.15.03-0042-000
# 25.94.11.110.22.2.02.11-0021-000
# 0.40625
# 16.23.19.000.11.2.04.01-0001-000
# 16.23.19.000.11.2.04.01-0001-000
# 1.0
# 27.33.13.130.20.2.07.03-1061-000
# 16.10.10.110.11.1.03.01-0065-000
# 0.0
# 16.23.19.000.11.2.04.01-0001-000
# 16.10.10.110.11.1.03.01-0065-000
# 0.09375
# 16.10.21.110.59.1.11.01-0467-000
# 16.23.19.000.11.1.03.07-0012-000
# 0.09375
# 16.10.21.110.59.1.11.01-0467-000
# 16.23.19.000.11.1.03.07-0012-000
# 0.09375
# 27.33.13.130.20.2.07.03-1061-000
# 16.23.19.000.11.1.03.07-0012-000
# 0.0
# 16.10.21.110.59.1.11.01-0467-000
# 16.23.19.000.11.1.03.07-0012-000
# 0.09375
# 16.10.21.110.59.1.11.01-0467-000
# 16.23.19.000.11.1.03.07-0012-000
# 0.09375
# 16.10.21.110.59.1.11.01-0467-000
# 16.23.19.000.11.1.03.07-0012-000
# 0.09375
# 16.10.21.110.59.1.11.01-0467-000
# 16.23.19.000.11.1.03.07-0012-000
# 0.09375
# 16.10.21.110.59.1.11.01-0467-000
# 16.23.19.000.11.1.03.07-0012-000
# 0.09375
# 23.61.11.190.59.1.05.02-0208-000
# 23.70.12.110.05.2.02.12-1026-000
# 0.09375
# 23.61.11.190.59.1.05.02-0208-000
# 23.70.12.110.05.2.02.12-1026-000
# 0.09375
# 25.73.40.119.01.7.17.09-1135-000
# 25.73.40.119.01.7.17.09-1002-000
# 0.78125
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1262-000
# 0.1875
# 27.40.33.190.20.3.04.04-0034-000
# 25.73.40.119.01.7.17.09-1262-000
# 0.03125
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.40.119.01.7.17.09-1013-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.84375
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0038-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.1875
# 27.40.33.190.20.3.04.04-0034-000
# 25.73.40.119.01.7.17.09-1016-000
# 0.03125
# 16.23.19.000.59.1.11.02-0849-000
# 25.73.40.119.01.7.17.09-1013-000
# 0.0
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1013-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1013-000
# 0.1875
# 25.73.60.120.59.1.01.04-0044-000
# 25.73.40.119.01.7.17.09-1013-000
# 0.1875
# 25.73.60.120.59.1.01.04-0039-000
# 25.73.40.119.01.7.17.09-1013-000
# 0.1875
# 25.73.60.120.59.1.01.04-0037-000
# 25.73.40.119.01.7.17.09-1013-000
# 0.1875
# 25.73.60.120.59.1.01.04-0037-000
# 25.73.40.119.01.7.17.09-1013-000
# 0.1875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[303], line 4
#       2 for i, r in val_data.iterrows():
#       3     Y = cv.transform(list(map(get_lemm, [r["text_lemm"]])))
# ----> 4     found = clsf["code"].iloc[np.argmin(cosine_distances(X, Y))]
#       5     real = r["ref_code"]
#       6     print(found)
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\pairwise.py:1108, in cosine_distances(X, Y)
#    1073 """Compute cosine distance between samples in X and Y.
#    1074
#    1075 Cosine distance is defined as 1.0 minus the cosine similarity.
#    (...)
#    1105        [0.42..., 0.18...]])
#    1106 """
#    1107 # 1.0 - cosine_similarity(X, Y) without copy
# -> 1108 S = cosine_similarity(X, Y)
#    1109 S *= -1
#    1110 S += 1
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\pairwise.py:1657, in cosine_similarity(X, Y, dense_output)
#    1613 """Compute cosine similarity between samples in X and Y.
#    1614
#    1615 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1653        [0.57..., 0.81...]])
#    1654 """
#    1655 # to avoid recursive import
# -> 1657 X, Y = check_pairwise_arrays(X, Y)
#    1659 X_normalized = normalize(X, copy=True)
#    1660 if X is Y:
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\pairwise.py:164, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     155     X = Y = check_array(
#     156         X,
#     157         accept_sparse=accept_sparse,
#    (...)
#     161         estimator=estimator,
#     162     )
#     163 else:
# --> 164     X = check_array(
#     165         X,
#     166         accept_sparse=accept_sparse,
#     167         dtype=dtype,
#     168         copy=copy,
#     169         force_all_finite=force_all_finite,
#     170         estimator=estimator,
#     171     )
#     172     Y = check_array(
#     173         Y,
#     174         accept_sparse=accept_sparse,
#    (...)
#     178         estimator=estimator,
#     179     )
#     181 if precomputed:
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:963, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     961 if sp.issparse(array):
#     962     _ensure_no_complex_data(array)
# --> 963     array = _ensure_sparse_format(
#     964         array,
#     965         accept_sparse=accept_sparse,
#     966         dtype=dtype,
#     967         copy=copy,
#     968         force_all_finite=force_all_finite,
#     969         accept_large_sparse=accept_large_sparse,
#     970         estimator_name=estimator_name,
#     971         input_name=input_name,
#     972     )
#     973 else:
#     974     # If np.array(..) gives ComplexWarning, then we convert the warning
#     975     # to an error. This is needed because specifying a non complex
#     976     # dtype to the function converts complex to real dtype,
#     977     # thereby passing the test made in the lines following the scope
#     978     # of warnings context manager.
#     979     with warnings.catch_warnings():
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:619, in _ensure_sparse_format(sparse_container, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse, estimator_name, input_name)
#     612     raise ValueError(
#     613         "Parameter 'accept_sparse' should be a string, boolean or list of strings."
#     614         f" You provided 'accept_sparse={accept_sparse}'."
#     615     )
#     617 if dtype != sparse_container.dtype:
#     618     # convert dtype
# --> 619     sparse_container = sparse_container.astype(dtype)
#     620 elif copy and not changed_format:
#     621     # force copy
#     622     sparse_container = sparse_container.copy()
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\_data.py:75, in _data_matrix.astype(self, dtype, casting, copy)
#      70 if self.dtype != dtype:
#      71     matrix = self._with_data(
#      72         self.data.astype(dtype, casting=casting, copy=True),
#      73         copy=True
#      74     )
# ---> 75     return matrix._with_data(matrix._deduped_data(), copy=False)
#      76 elif copy:
#      77     return self.copy()
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\_data.py:32, in _data_matrix._deduped_data(self)
#      30 def _deduped_data(self):
#      31     if hasattr(self, 'sum_duplicates'):
# ---> 32         self.sum_duplicates()
#      33     return self.data
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\_compressed.py:1117, in _cs_matrix.sum_duplicates(self)
#    1115 if self.has_canonical_format:
#    1116     return
# -> 1117 self.sort_indices()
#    1119 M, N = self._swap(self.shape)
#    1120 _sparsetools.csr_sum_duplicates(M, N, self.indptr, self.indices,
#    1121                                 self.data)
#
# File c:\Users\chernov\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\sparse\_compressed.py:1163, in _cs_matrix.sort_indices(self)
#    1159 """Sort the indices of this matrix *in place*
#    1160 """
#    1162 if not self.has_sorted_indices:
# -> 1163     _sparsetools.csr_sort_indices(len(self.indptr) - 1, self.indptr,
#    1164                                   self.indices, self.data)
#    1165     self.has_sorted_indices = True
#
# KeyboardInterrupt:

# %%
np.average(scores)
# Out:
# 0.37774122807017546
