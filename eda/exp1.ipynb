# %%
import pandas as pd

# %%
classification = pd.read_excel('../data/train_Ametist/classification.xlsx')

# %%
classification.head(29)
# Out:
#                   Классификатор строительных ресурсов
# 0                                         Код ресурса  \
# 1   Книга 01: Материалы для строительных и дорожны...
# 2   Часть 01.1: Материалы, изделия и конструкции х...
# 3   Раздел 01.1.01: Материалы, изделия и конструкц...
# 4   Группа 01.1.01.01: Детали фасонные к листам хр...
# 5                                     01.1.01.01-0002
# 6                    23.65.12.190.01.1.01.01-0002-000
# 7         Группа 01.1.01.02: Доски электротехнические
# 8                                     01.1.01.02-0011
# 9                    23.65.12.190.01.1.01.02-0011-000
# 10  Группа 01.1.01.04: Листы хризотилцементные вол...
# 11                                    01.1.01.04-1018
# 12                   23.65.12.111.01.1.01.04-1018-000
# 13                                    01.1.01.04-1022
# 14                   23.65.12.111.01.1.01.04-1022-000
# 15                                    01.1.01.04-1024
# ...
